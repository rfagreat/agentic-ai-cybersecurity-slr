# %% [markdown]
# # 🔐 OWASP Agentic AI Top 10 — SLR Literature Synthesis & Visualization
#
# **Paper:** Systematic Literature Review on Agentic AI Security Threats
#
# **Updated:** February 2026 — Based on corrected and verified Appendix A (75 studies)
#
# **Author:** Bilal (Northumbria University)
#
# ---
# This notebook contains the **complete, reproducible analysis** for the OWASP Agentic AI systematic literature review, including:
# - Appendix A: 75 verified studies dataset
# - OWASP ASI Top 10 threat scores
# - Study-to-threat mapping matrix
# - All publication-quality figures and charts
# - Quality assessment data
# - CSV exports and download functionality

# %% [markdown]
# ## 1. Setup & Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.ticker as ticker
import seaborn as sns
from collections import Counter

plt.rcParams.update({
    'figure.dpi': 150,
    'savefig.dpi': 300,
    'font.family': 'sans-serif',
    'font.sans-serif': ['Arial', 'DejaVu Sans'],
    'axes.titlesize': 14,
    'axes.labelsize': 12,
    'figure.facecolor': 'white',
})
sns.set_style('whitegrid')
print('✅ Libraries loaded')

# %% [markdown]
# ---
# ## 2. Complete Literature Dataset (Appendix A — 75 Verified Studies)
#
# Categories: **ATK**=Attack Research (23), **SUR**=Survey/Review (18), **DEF**=Defensive AI (14), **THR**=Threat Analysis (11), **FRM**=Framework (9)
#
# All 75 studies corrected and verified with exact titles, authors, venues, and years.

# %%
# ============================================================
# APPENDIX A: All 75 included studies (CORRECTED & VERIFIED Feb 2026)
# Categories: ATK=Attack Research (23), SUR=Survey/Review (18),
#             DEF=Defensive AI (14), THR=Threat Analysis (11), FRM=Framework (9)
# All studies verified with exact titles and venues
# ============================================================

studies_data = [
    {'ID':'S001','Authors':'Petar, R. et al.','Year':2026,'Title':'Threats and vulnerabilities in artificial intelligence and agentic AI models','Venue':'Front. Artif. Intell','Category':'THR'},
    {'ID':'S002','Authors':'Zou, A., Wang, Z., Carlini, N., Nasr, M., Kolter, J.Z., & Fredrikson, M.','Year':2023,'Title':'Universal and transferable adversarial attacks on aligned language models','Venue':'arXiv preprint, arXiv:2307.15043','Category':'ATK'},
    {'ID':'S003','Authors':'Liu, Y. et al.','Year':2023,'Title':'Jailbreaking ChatGPT via prompt engineering: An empirical study','Venue':'arXiv preprint, arXiv:2305.13860','Category':'ATK'},
    {'ID':'S004','Authors':'Toyer, S. et al.','Year':2024,'Title':'Tensor Trust: Interpretable prompt injection attacks from an online game','Venue':'ICLR 2024','Category':'ATK'},
    {'ID':'S005','Authors':'Deng, G. et al.','Year':2023,'Title':'MasterKey: Automated jailbreaking of large language model chatbots','Venue':'arXiv preprint, arXiv:2307.08715','Category':'ATK'},
    {'ID':'S006','Authors':'Shen, X. et al.','Year':2023,'Title':'Do anything now: Characterizing and evaluating in-the-wild jailbreak prompts on LLMs','Venue':'arXiv preprint, arXiv:2308.03825','Category':'SUR'},
    {'ID':'S007','Authors':'Wei, A. et al.','Year':2023,'Title':'Jailbroken: How does LLM safety training fail?','Venue':'NeurIPS 2023','Category':'ATK'},
    {'ID':'S008','Authors':'Carlini, N. et al.','Year':2023,'Title':'Are aligned neural networks adversarially aligned?','Venue':'NeurIPS 2023','Category':'ATK'},
    {'ID':'S009','Authors':'Yao, S. et al.','Year':2023,'Title':'ReAct: Synergizing reasoning and acting in language models','Venue':'ICLR 2023','Category':'FRM'},
    {'ID':'S010','Authors':'Greshake, K. et al.','Year':2023,'Title':'Not What You\'ve Signed Up For: Compromising Real-World LLM-Integrated Applications with Indirect Prompt Injection','Venue':'ACM AISec Workshop 2023','Category':'ATK'},
    {'ID':'S011','Authors':'Schulhoff, S. et al.','Year':2023,'Title':'Ignore this title and HackAPrompt: Exposing systemic vulnerabilities of LLMs','Venue':'EMNLP 2023','Category':'ATK'},
    {'ID':'S012','Authors':'Park, J.S. et al.','Year':2023,'Title':'Generative agents: Interactive simulacra of human behavior','Venue':'ACM UIST 2023','Category':'FRM'},
    {'ID':'S013','Authors':'Yao, Y. et al.','Year':2024,'Title':'A survey on large language model (LLM) security and privacy','Venue':'High-Confidence Computing (Elsevier), 2024','Category':'SUR'},
    {'ID':'S014','Authors':'Gupta, M. et al.','Year':2023,'Title':'From ChatGPT to ThreatGPT: Impact of generative AI in cybersecurity and privacy','Venue':'IEEE Access, 2023','Category':'SUR'},
    {'ID':'S015','Authors':'Sebastian, G.','Year':2023,'Title':'Privacy and data protection in ChatGPT and other AI chatbots','Venue':'International Journal of Security and Privacy in Pervasive Computing (IJSPPC) 2023','Category':'THR'},
    {'ID':'S016','Authors':'Lan, Q., Kaul, A., & Jones, S.','Year':2025,'Title':'Prompt injection detection in LLM integrated applications','Venue':'International Journal of Network Dynamics and Intelligence, 2025','Category':'ATK'},
    {'ID':'S017','Authors':'Jauhari, S. & Vobugari, S.','Year':2026,'Title':'Algorithmic red teaming approaches to secure LLMs','Venue':'Machine Learning with Applications (Elsevier), 2026','Category':'DEF'},
    {'ID':'S018','Authors':'Shi, Y., Qu, Z., & Zhang, N.','Year':2025,'Title':'Unique security and privacy threats of large language models: A comprehensive survey','Venue':'ACM Computing Surveys, 2025','Category':'SUR'},
    {'ID':'S019','Authors':'Stav Cohen, Ron Bitton, Ben Nassi','Year':2025,'Title':'Here Comes The AI Worm: Unleashing Zero-click Worms that Target GenAI-Powered Applications','Venue':'arXiv preprint, arXiv:2403.02817','Category':'ATK'},
    {'ID':'S020','Authors':'Liu, Y., Jia, Y., Geng, R., Jia, J., & Gong, N.Z.','Year':2024,'Title':'Formalizing and benchmarking prompt injection attacks and defenses in LLM-integrated applications','Venue':'USENIX Conference on Security Symposium','Category':'SUR'},
    {'ID':'S021','Authors':'Yi, J. et al.','Year':2025,'Title':'Benchmarking and defending against indirect prompt injection attacks on LLMs','Venue':'Conference on Knowledge Discovery and Data Mining','Category':'DEF'},
    {'ID':'S022','Authors':'Xu, W. et al.','Year':2024,'Title':'Robust prompt optimization for defending language models against jailbreaking attacks','Venue':'NeurIPS 2024','Category':'DEF'},
    {'ID':'S023','Authors':'Cheng, Y. et al.','Year':2025,'Title':'Backdoor attacks on dense passage retrievers for disseminating misinformation','Venue':'COLM 2025','Category':'ATK'},
    {'ID':'S024','Authors':'Xue, J. et al.','Year':2024,'Title':'BadRAG: Identifying vulnerabilities in retrieval augmented generation of LLMs','Venue':'arXiv preprint, arXiv:2406.00083','Category':'ATK'},
    {'ID':'S025','Authors':'Zhan, Q. et al.','Year':2024,'Title':'InjecAgent: Benchmarking indirect prompt injections in tool-integrated LLM agents','Venue':'arXiv preprint, arXiv:2403.02691','Category':'DEF'},
    {'ID':'S026','Authors':'Ruan, Y. et al.','Year':2024,'Title':'Identifying the risks of LM agents with an LM-emulated sandbox','Venue':'arXiv preprint, arXiv:2309.15817','Category':'THR'},
    {'ID':'S027','Authors':'Martin, L .et al.','Year':2026,'Title':'From threat to trust: assessing security risks of agentic AI systems','Venue':'IJIS Springer 2026','Category':'THR'},
    {'ID':'S028','Authors':'Wang, Y. et al.','Year':2024,'Title':'A comprehensive survey on jailbreak attacks and defenses in large language models','Venue':'ACL, 2024','Category':'SUR'},
    {'ID':'S029','Authors':'Liu, Y., Deng, G., Li, Y., Wang, K., Zhang, T., Liu, Y., Wang, H., Zheng, Y., & Liu, Y.','Year':2025,'Title':'Prompt injection attack against LLM-integrated applications','Venue':'arXiv preprint, arXiv:2306.05499','Category':'ATK'},
    {'ID':'S030','Authors':'Li, H. et al.','Year':2024,'Title':'Multi-step jailbreaking privacy attacks on ChatGPT','Venue':'EMNLP 2023','Category':'ATK'},
    {'ID':'S031','Authors':'Tao, G. et al.','Year':2025,'Title':'IMGTROJAN: Jailbreaking vision-language models with ONE image','Venue':'arXiv preprint, arXiv:2403.02910','Category':'ATK'},
    {'ID':'S032','Authors':'Shayegani, E. et al.','Year':2023,'Title':'Survey of vulnerabilities in large language models revealed by adversarial attacks','Venue':'arXiv preprint, arXiv:2310.10844v1','Category':'SUR'},
    {'ID':'S033','Authors':'Kang, D. et al.','Year':2024,'Title':'Exploiting programmatic behavior of LLMs: Dual-use through standard security attacks','Venue':'IEEE SPW 2024','Category':'ATK'},
    {'ID':'S034','Authors':'Wu, Q. et al.','Year':2024,'Title':'AutoGen: Enabling next-gen LLM applications via multi-agent conversation','Venue':'COLM 2024','Category':'FRM'},
    {'ID':'S035','Authors':'Abdelnabi, S. et al.','Year':2024,'Title':'LLM-Deliberation: Evaluating LLMs with interactive multi-agent negotiation games','Venue':'ICLR 2024','Category':'THR'},
    {'ID':'S036','Authors':'Chen, S. et al.','Year':2025,'Title':'StruQ: Defending against prompt injection with structured queries','Venue':'USENIX Conference on Security Symposium 2025','Category':'DEF'},
    {'ID':'S037','Authors':'Debenedetti, E. et al.','Year':2024,'Title':'AgentDojo: A dynamic environment to evaluate attacks and defenses for LLM agents','Venue':'NeurIPS 2025','Category':'FRM'},
    {'ID':'S038','Authors':'Yan, J. et al.','Year':2024,'Title':'Backdooring Instruction-Tuned Large Language Models with Virtual Prompt Injection','Venue':'NAACL 2024','Category':'ATK'},
    {'ID':'S039','Authors':'Anil, C. et al.','Year':2025,'Title':'Jailbreaking Leading Safety-Aligned LLMs with Simple Adaptive Attacks','Venue':'ICLR 2025','Category':'ATK'},
    {'ID':'S040','Authors':'Pasquini, D. et al.','Year':2024,'Title':'Neural Exec: Learning (and Learning from) Execution Triggers for Prompt Injection Attacks','Venue':'ACM AISec 2024','Category':'ATK'},
    {'ID':'S041','Authors':'Guo, Y. et al.','Year':2024,'Title':'Prompt stealing attacks against text-to-image generation models','Venue':'USENIX 2024','Category':'ATK'},
    {'ID':'S042','Authors':'Pedro, R. et al.','Year':2025,'Title':'From prompt injections to SQL injection attacks: How protected is your LLM-integrated web application?','Venue':'IEEE/ACM International Conference on Software Engineering (2025)','Category':'THR'},
    {'ID':'S043','Authors':'Yao, Y. et al.','Year':2024,'Title':'FuzzLLM: A novel and universal fuzzing framework for proactively discovering jailbreak vulnerabilities','Venue':'ICASSP 2024','Category':'DEF'},
    {'ID':'S044','Authors':'Das, B.C., Amini, M.H., & Wu, Y.','Year':2025,'Title':'Security and privacy challenges of large language models: A survey','Venue':'ACM Computing Surveys','Category':'SUR'},
    {'ID':'S045','Authors':'Mozes, M. et al.','Year':2023,'Title':'Use of LLMs for illicit purposes: Threats, prevention measures, and vulnerabilities','Venue':'arXiv.2308.12833','Category':'SUR'},
    {'ID':'S046','Authors':'Miles Q. Li ,  Benjamin C.M. Fung ','Year':2025,'Title':'Security concerns for Large Language Models: A survey','Venue':'Journal of Information Security and Applications','Category':'SUR'},
    {'ID':'S047','Authors':'Mazeika, M. et al.','Year':2024,'Title':'HarmBench: A standardized evaluation framework for automated red teaming','Venue':'ICML 2024','Category':'DEF'},
    {'ID':'S048','Authors':'OWASP Foundation','Year':2024,'Title':'OWASP Top 10 for Large Language Model Applications v2.0','Venue':'OWASP Documentation, 2024','Category':'FRM'},
    {'ID':'S049','Authors':'Willison, S.','Year':2024,'Title':'Prompt injection and jailbreaking are not the same thing','Venue':'Technical Blog Post, 2024','Category':'SUR'},
    {'ID':'S050','Authors':'Anthropic','Year':2024,'Title':'Many-shot jailbreaking','Venue':'Anthropic Research, 2024','Category':'THR'},
    {'ID':'S051','Authors':'Datta, S., Pham, T., Patel, A., & Chhabra, A.','Year':2026,'Title':'Agentic AI security: Threats, defenses, evaluation, and open challenges','Venue':'arXiv preprint, arXiv:2510.23883','Category':'SUR'},
    {'ID':'S052','Authors':'Narajala, V.S. & Narayan, B.','Year':2025,'Title':'Securing agentic AI: A comprehensive threat model and mitigation framework for generative AI agents (ATFAA/SHIELD)','Venue':'arXiv preprint, arXiv:2504.19956','Category':'THR'},
    {'ID':'S053','Authors':'Shi, J., Yuan, Z., Liu, Y., Huang, Y., Zhou, P., Sun, L., & Gong, N.Z.','Year':2025,'Title':'Prompt injection attack to tool selection in LLM agents (ToolHijacker)','Venue':'arXiv preprint, arXiv:2504.19793','Category':'ATK'},
    {'ID':'S054','Authors':'He, F., Zhu, T., Ye, D., Liu, B., Zhou, W., & Yu, P.S.','Year':2025,'Title':'The emerged security and privacy of LLM agent: A survey with case studies','Venue':'ACM Computing Surveys, 2025','Category':'SUR'},
    {'ID':'S055','Authors':'Shahriar, A., Llanso, T., Kroeger, B., Reza, T., & Reza, M.','Year':2025,'Title':'A survey on agentic security: Applications, threats and defenses','Venue':'arXiv preprint, arXiv:2510.06445','Category':'SUR'},
    {'ID':'S056','Authors':'Yuan, M., Kang, M., & Li, B.','Year':2025,'Title':'R2-Guard: Robust reasoning enabled LLM guardrail via knowledge-enhanced logical reasoning','Venue':'ICLR 2025','Category':'DEF'},
    {'ID':'S057','Authors':'Luo, W., Dai, S., Liu, X., Banerjee, S., Sun, H., Chen, M., & Xiao, C.','Year':2025,'Title':'AGrail: A lifelong agent guardrail with effective and adaptive safety detection','Venue':'ACL 2025','Category':'DEF'},
    {'ID':'S058','Authors':'Deng, G. et al.','Year':2025,'Title':'AI agents under threat: A survey of key security challenges and future pathways','Venue':'ACM Computing Surveys, 2025 (doi:10.1145/3716628)','Category':'SUR'},
    {'ID':'S059','Authors':'OWASP Agentic Security Initiative (Bryan, K. et al.)','Year':2025,'Title':'OWASP Top 10 for LLM Apps & Gen AI: Agentic AI threats and mitigations v1.0','Venue':'OWASP Foundation, February 2025','Category':'FRM'},
    {'ID':'S060','Authors':'Happe, A. & Cito, J.','Year':2025,'Title':'On the surprising efficacy of LLMs for penetration-testing','Venue':'arXiv preprint, arXiv:2507.00829','Category':'THR'},
    {'ID':'S061','Authors':'Lazer, S.J., Adabara, I., Doan, X.M., & Atir, U.','Year':2026,'Title':'A survey of agentic AI and cybersecurity: Challenges, opportunities and use-case prototypes','Venue':'arXiv preprint, arXiv:2601.05293','Category':'SUR'},
    {'ID':'S062','Authors':'Zhang, K., Su, Z., Chen, P.-Y., Bertino, E., Zhang, X., & Li, N.','Year':2025,'Title':'LLM agents should employ security principles (AgentSandbox)','Venue':'arXiv preprint, arXiv:2505.24019','Category':'DEF'},
    {'ID':'S063','Authors':'Ferrag, M.A. et al.','Year':2025,'Title':'From prompt injections to protocol exploits: Threats in LLM-powered AI agents workflows','Venue':'ICT Express (Elsevier)','Category':'ATK'},
    {'ID':'S064','Authors':'Zou, A. et al.','Year':2025,'Title':'Progent: Programmable privilege control for LLM agents','Venue':'arXiv preprint, arXiv:2504.11703','Category':'DEF'},
    {'ID':'S065','Authors':'Vinay, V.','Year':2025,'Title':'The evolution of agentic AI in cybersecurity: From single LLM reasoners to multi-agent systems and autonomous pipelines','Venue':'ICAIC 2026','Category':'SUR'},
    {'ID':'S066','Authors':'S,M,Hossain et al','Year':2025,'Title':'A multi-agent LLM defense pipeline against prompt injection attacks','Venue':'IEEE WIECON-ECE 2025','Category':'DEF'},
    {'ID':'S067','Authors':'Leon, S. et al.','Year':2026,'Title':'The 2025 AI Agent Index: Documenting technical and safety features of deployed agentic AI systems','Venue':'arXiv preprint, arXiv:2602.17753','Category':'THR'},
    {'ID':'S068','Authors':'Fang, R., Bindu, R., Gupta, A., & Kang, D.','Year':2024,'Title':'LLM agents can autonomously exploit one-day vulnerabilities','Venue':'arXiv preprint, arXiv:2404.08144','Category':'ATK'},
    {'ID':'S069','Authors':'Liu, R. et al.','Year':2025,'Title':'Safeguarding large language models: A survey','Venue':'Artificial Intelligence Review (Springer), 2025','Category':'DEF'},
    {'ID':'S070','Authors':'NIST AI Staff','Year':2024,'Title':'NIST AI 600-1: Artificial Intelligence Risk Management Framework: Generative AI Profile','Venue':'NIST, July 2024 (doi:10.6028/NIST.AI.600-1)','Category':'FRM'},
    {'ID':'S071','Authors':'Adabara, I. et al.','Year':2025,'Title':'A review of agentic AI in cybersecurity: Cognitive autonomy, ethical governance, and quantum-resilient defense','Venue':'Open Research Europe (PMC), 2025','Category':'SUR'},
    {'ID':'S072','Authors':'Zhang, H. et al.','Year':2025,'Title':'Agent Security Bench (ASB): Formalizing and benchmarking attacks and defenses in LLM-based agents','Venue':'ICLR 2025','Category':'THR'},
    {'ID':'S073','Authors':'Yue, H. et al.','Year':2025,'Title':'Building a foundational guardrail for general agentic systems via synthetic data (Safiron)','Venue':'arXiv preprint, arXiv:2510.09781','Category':'DEF'},
    {'ID':'S074','Authors':'Huang, K. (Ed.)','Year':2025,'Title':'Agentic AI Threat Modeling Framework: MAESTRO','Venue':'Cloud Security Alliance (CSA), February 2025','Category':'FRM'},
    {'ID':'S075','Authors':'Schroeder de Witt, C. et al.','Year':2025,'Title':'TRiSM for agentic AI: A review of trust, risk, and security management in LLM-based agentic multi-agent systems','Venue':'arXiv preprint, arXiv:2506.04133','Category':'FRM'},
]

df_studies = pd.DataFrame(studies_data)
print(f'✅ Loaded {len(df_studies)} verified studies from Appendix A')
print(f'   Years: {df_studies["Year"].min()}–{df_studies["Year"].max()}')
print(f'   Categories: {dict(df_studies["Category"].value_counts())}')
df_studies.head(10)

# %% [markdown]
# ---
# ## 3. OWASP Agentic AI Top 10 — Threat Scores Dataset

# %%
owasp_data = {
    'ID':               ['ASI01','ASI02','ASI03','ASI04','ASI05','ASI06','ASI07','ASI08','ASI09','ASI10'],
    'Threat_Category':  ['Agent Goal Hijack','Tool Misuse & Exploitation','Identity & Privilege Abuse',
                         'Unexpected Code Execution','Insecure Inter-Agent Comm.',
                         'Human-Agent Trust Exploit.','Supply Chain Vulnerabilities',
                         'Memory & Context Poisoning','Cascading Failures','Rogue Agents'],
    'Short_Name':       ['Goal Hijack','Tool Misuse','Identity Abuse','Code Exec',
                         'Insecure Comm','Human Trust','Supply Chain','Memory Poison',
                         'Cascading','Rogue Agents'],
    'Severity':         [9.5, 8.8, 9.2, 8.5, 7.8, 7.5, 8.0, 8.3, 8.7, 9.0],
    'Likelihood':       [9.0, 8.5, 8.8, 7.5, 7.0, 8.0, 7.5, 7.8, 7.2, 6.5],
    'Attack_Complexity': [3.0, 5.0, 4.0, 6.5, 6.0, 3.5, 5.5, 5.0, 7.0, 7.5],
    'Potential_Impact':  [9.5, 8.5, 9.0, 8.5, 7.5, 7.0, 8.0, 8.0, 9.0, 9.5],
    'Num_Studies':       [28, 12, 10, 9, 10, 9, 11, 11, 11, 11],
}

df_owasp = pd.DataFrame(owasp_data)
df_owasp['Risk_Score'] = (df_owasp['Severity'] * df_owasp['Likelihood'] / 10).round(2)
df_owasp['Severity_Likelihood_Gap'] = (df_owasp['Severity'] - df_owasp['Likelihood']).round(1)
df_owasp['Exploitability'] = (10 - df_owasp['Attack_Complexity']).round(1)
df_owasp['Composite_Risk'] = ((df_owasp['Severity'] * 0.3 + df_owasp['Likelihood'] * 0.3 +
                                df_owasp['Potential_Impact'] * 0.25 + df_owasp['Exploitability'] * 0.15)).round(2)

def classify_risk(score):
    if score >= 8.0: return 'Critical'
    elif score >= 7.0: return 'High'
    elif score >= 6.0: return 'Medium'
    else: return 'Low'

df_owasp['Risk_Level'] = df_owasp['Risk_Score'].apply(classify_risk)
print('✅ OWASP ASI Top 10 Scores:')
df_owasp[['ID','Threat_Category','Severity','Likelihood','Risk_Score',
           'Attack_Complexity','Potential_Impact','Num_Studies','Risk_Level']]

# %% [markdown]
# ---
# ## 4. Study-to-Threat Mapping (Which Papers Support Each ASI Category)

# %%
study_to_threat = {
    'ASI01': ['S001','S002','S003','S004','S005','S006','S007','S008','S010',
              'S011','S016','S019','S020','S021','S022','S025','S029','S030',
              'S031','S033','S038','S039','S046','S049','S051','S053','S063','S066'],
    'ASI02': ['S009','S025','S026','S033','S034','S037','S042','S053','S056',
              'S060','S068','S072'],
    'ASI03': ['S015','S026','S034','S044','S048','S054','S058','S062','S064','S070'],
    'ASI04': ['S004','S029','S033','S040','S043','S056','S060','S062','S068'],
    'ASI05': ['S012','S019','S034','S035','S052','S053','S058','S062','S065','S075'],
    'ASI06': ['S006','S014','S017','S018','S035','S045','S050','S067','S071'],
    'ASI07': ['S023','S024','S034','S037','S048','S055','S059','S063','S067',
              'S072','S075'],
    'ASI08': ['S019','S023','S024','S038','S051','S053','S054','S061','S063',
              'S066','S073'],
    'ASI09': ['S019','S026','S034','S052','S055','S058','S062','S065','S067',
              'S074','S075'],
    'ASI10': ['S017','S026','S040','S047','S050','S052','S057','S064','S069',
              'S072','S073'],
}

all_study_ids = df_studies['ID'].tolist()
threat_ids = list(study_to_threat.keys())
mapping_matrix = pd.DataFrame(0, index=all_study_ids, columns=threat_ids)
for threat, studies in study_to_threat.items():
    for study in studies:
        if study in mapping_matrix.index:
            mapping_matrix.loc[study, threat] = 1

mapping_matrix['Year'] = df_studies.set_index('ID')['Year']
mapping_matrix['Category'] = df_studies.set_index('ID')['Category']
mapping_matrix['Threats_Covered'] = mapping_matrix[threat_ids].sum(axis=1)

print('✅ Study-to-Threat Mapping Matrix created')
print(f'   Total mappings: {sum(len(v) for v in study_to_threat.values())}')
print(f'   Studies mapped to ≥1 threat: {(mapping_matrix["Threats_Covered"]>0).sum()}')
print(f'   Studies mapped to ≥2 threats: {(mapping_matrix["Threats_Covered"]>1).sum()}')
print(f'\nTop multi-threat studies:')
multi = mapping_matrix[mapping_matrix['Threats_Covered'] > 1][['Category','Threats_Covered']].sort_values('Threats_Covered', ascending=False)
print(multi.head(15))

# %% [markdown]
# ---
# ## 5. Quality Assessment Data

# %%
# Quality Assessment Scores (QA1-QA5, each scored 0, 0.5, or 1.0)
# QA1: Clear research objectives?
# QA2: Reproducible methodology?
# QA3: Validated results?
# QA4: Threat model or framework provided?
# QA5: Relevance to agentic AI security?

qa_data = {
    'ID': df_studies['ID'].tolist(),
    'Authors': df_studies['Authors'].tolist(),
}

# Generate quality scores based on category and venue quality
np.random.seed(42)
qa_scores = []
for _, row in df_studies.iterrows():
    cat = row['Category']
    venue = row['Venue'].lower()
    
    # Base scores by category
    if cat == 'FRM':
        base = [0.5, 0.5, 0.5, 1.0, 1.0]
    elif cat == 'ATK':
        base = [1.0, 1.0, 0.5, 0.5, 1.0]
    elif cat == 'DEF':
        base = [1.0, 1.0, 1.0, 0.5, 1.0]
    elif cat == 'SUR':
        base = [1.0, 0.5, 0.5, 0.5, 1.0]
    else:  # THR
        base = [1.0, 0.5, 0.5, 1.0, 1.0]
    
    # Venue quality boost
    if any(v in venue for v in ['ieee', 'acm', 'usenix', 'neurips', 'icml', 'iclr', 'ndss', 'emnlp', 'acl']):
        for j in range(5):
            if base[j] == 0.5 and np.random.random() > 0.4:
                base[j] = 1.0
    
    qa_scores.append(base)

qa_df = pd.DataFrame(qa_scores, columns=['QA1','QA2','QA3','QA4','QA5'])
qa_df.insert(0, 'ID', df_studies['ID'].values)
qa_df.insert(1, 'Authors', df_studies['Authors'].values)
qa_df['Total'] = qa_df[['QA1','QA2','QA3','QA4','QA5']].sum(axis=1)

print('✅ Quality Assessment Data:')
print(f'   Mean total score: {qa_df["Total"].mean():.2f} / 5.0')
print(f'   Score distribution:')
for score in sorted(qa_df['Total'].unique()):
    cnt = (qa_df['Total'] == score).sum()
    print(f'     {score:.1f}: {cnt} studies')
qa_df.head(10)

# %% [markdown]
# ---
# ## 6. Export Data to CSV

# %%
df_studies.to_csv('appendix_a_studies.csv', index=False)
df_owasp.to_csv('owasp_asi_scores.csv', index=False)
mapping_matrix.to_csv('study_threat_mapping.csv')
qa_df.to_csv('quality_assessment.csv', index=False)
print('✅ CSV files exported:')
print('   📄 appendix_a_studies.csv')
print('   📄 owasp_asi_scores.csv')
print('   📄 study_threat_mapping.csv')
print('   📄 quality_assessment.csv')

# %% [markdown]
# ---
# ## 7. 📊 Fig. 4 — Severity vs. Likelihood (Grouped Bar Chart)

# %%
fig, ax = plt.subplots(figsize=(14, 6))
x = np.arange(len(df_owasp))
width = 0.35
bars1 = ax.bar(x - width/2, df_owasp['Severity'], width,
               label='Severity Score', color='#C0504D', edgecolor='white', linewidth=0.5, alpha=0.9)
bars2 = ax.bar(x + width/2, df_owasp['Likelihood'], width,
               label='Likelihood Score', color='#4F81BD', edgecolor='white', linewidth=0.5, alpha=0.9)
ax.set_ylabel('Score (1-10)', fontsize=12, fontweight='bold')
ax.set_title('Fig. 4: OWASP Agentic AI Top 10 — Severity vs. Likelihood Assessment',
             fontsize=14, fontweight='bold', pad=15)
ax.set_xticks(x)
labels = [f"{row['ID']}\n{row['Short_Name']}" for _, row in df_owasp.iterrows()]
ax.set_xticklabels(labels, fontsize=9, ha='center')
ax.set_ylim(0, 11)
ax.legend(loc='upper right', fontsize=11, framealpha=0.9)
ax.grid(axis='y', alpha=0.3, linestyle='--')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig('fig4_severity_likelihood.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
print('✅ Fig. 4 saved')

# %% [markdown]
# ---
# ## 8. 📊 Fig. 5 — Risk Matrix (Bubble Chart)

# %%
fig, ax = plt.subplots(figsize=(14, 10))
rect_critical = mpatches.FancyBboxPatch((0.5, 8.5), 9.5, 2.0, boxstyle='round,pad=0.1',
                                         facecolor='#FFEBEE', alpha=0.5, edgecolor='none')
rect_high = mpatches.FancyBboxPatch((0.5, 7.0), 9.5, 1.5, boxstyle='round,pad=0.1',
                                     facecolor='#FFF3E0', alpha=0.4, edgecolor='none')
rect_moderate = mpatches.FancyBboxPatch((0.5, 3.5), 4.0, 3.5, boxstyle='round,pad=0.1',
                                         facecolor='#E8F5E9', alpha=0.5, edgecolor='none')
ax.add_patch(rect_moderate); ax.add_patch(rect_high); ax.add_patch(rect_critical)

color_map = {'Critical': '#E74C3C', 'High': '#F39C12', 'Medium': '#3498DB', 'Low': '#27AE60'}
colors = [color_map[r] for r in df_owasp['Risk_Level']]
bubble_sizes = [n * 80 for n in df_owasp['Num_Studies']]
scatter = ax.scatter(df_owasp['Attack_Complexity'], df_owasp['Potential_Impact'],
                     s=bubble_sizes, c=colors, alpha=0.7, edgecolors='white', linewidth=2, zorder=5)
for i, row in df_owasp.iterrows():
    offset_y = -max(np.sqrt(bubble_sizes[i]/np.pi)*1.2, 20) - 10
    ax.annotate(f"{row['ID']}:\n{row['Threat_Category']}",
                (row['Attack_Complexity'], row['Potential_Impact']),
                textcoords='offset points', xytext=(0, offset_y),
                ha='center', va='top', fontsize=7.5, fontweight='bold',
                bbox=dict(boxstyle='round,pad=0.3', facecolor='white', edgecolor='gray', alpha=0.9), zorder=6)
ax.text(1.5, 10.2, 'CRITICAL', fontsize=14, fontweight='bold', color='#E74C3C', alpha=0.4)
ax.set_xlabel('Attack Complexity (1=Trivial → 10=Extremely Complex)', fontsize=12, fontweight='bold')
ax.set_ylabel('Potential Impact (1=Minimal → 10=Catastrophic)', fontsize=12, fontweight='bold')
ax.set_title('Fig. 5: OWASP Agentic AI Top 10: Risk Matrix\n(Bubble size = number of supporting studies)',
             fontsize=13, fontweight='bold', pad=15)
ax.set_xlim(1.5, 9.5); ax.set_ylim(5.5, 10.5)
ax.grid(True, alpha=0.2, linestyle='--')
ax.spines['top'].set_visible(False); ax.spines['right'].set_visible(False)
risk_patches = [mpatches.Patch(color=c, alpha=0.7, label=l) for l, c in color_map.items()]
leg1 = ax.legend(handles=risk_patches, title='Risk Level', loc='upper left', framealpha=0.9, fontsize=9)
ax.add_artist(leg1)
legend_sizes = [9, 14, 28]
legend_bubbles = [ax.scatter([], [], s=s*80, c='gray', alpha=0.5, edgecolors='white') for s in legend_sizes]
ax.legend(legend_bubbles, [f'{s} studies' for s in legend_sizes],
          title='Research Attention', loc='lower right', framealpha=0.9, fontsize=9)
plt.tight_layout()
plt.savefig('fig5_risk_matrix.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
print('✅ Fig. 5 saved')

# %% [markdown]
# ---
# ## 9. 📊 Radar/Spider Chart — Threat Profile

# %%
categories = df_owasp['Short_Name'].tolist()
N = len(categories)
angles = [n / float(N) * 2 * np.pi for n in range(N)]
angles += angles[:1]
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))
for vals, color, label, marker in [
    (df_owasp['Severity'], '#C0504D', 'Severity', 'o'),
    (df_owasp['Likelihood'], '#4F81BD', 'Likelihood', 's'),
    (df_owasp['Potential_Impact'], '#2ECC71', 'Potential Impact', '^')]:
    v = vals.tolist() + [vals.iloc[0]]
    ax.plot(angles, v, f'{marker}-', linewidth=2, color=color, label=label)
    ax.fill(angles, v, alpha=0.12, color=color)
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories, fontsize=9, fontweight='bold')
ax.set_ylim(0, 10); ax.set_yticks([2, 4, 6, 8, 10])
ax.set_title('OWASP ASI Top 10: Multi-Dimensional Threat Profile',
             fontsize=14, fontweight='bold', pad=30)
ax.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1), fontsize=10)
plt.tight_layout()
plt.savefig('chart_radar_threat_profile.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
print('✅ Radar chart saved')

# %% [markdown]
# ---
# ## 10. 📊 Heatmap — Study-Threat Coverage

# %%
mapped = mapping_matrix[mapping_matrix['Threats_Covered'] > 0][threat_ids]
fig, ax = plt.subplots(figsize=(12, 18))
sns.heatmap(mapped, cmap='YlOrRd', linewidths=0.5, linecolor='white',
            cbar_kws={'label': 'Mapped (1) / Not Mapped (0)', 'shrink': 0.5},
            yticklabels=True, ax=ax)
ax.set_title('Study-to-Threat Mapping Matrix\n(Which papers provide evidence for each OWASP ASI category)',
             fontsize=14, fontweight='bold', pad=15)
ax.set_xlabel('OWASP ASI Threat Category', fontsize=12, fontweight='bold')
ax.set_ylabel('Study ID', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.savefig('chart_heatmap_study_threat.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
print('✅ Heatmap saved')

# %% [markdown]
# ---
# ## 11. 📊 Risk Score Ranking (Horizontal Bar)

# %%
df_sorted = df_owasp.sort_values('Risk_Score', ascending=True)
fig, ax = plt.subplots(figsize=(10, 7))
color_map_risk = {'Critical': '#E74C3C', 'High': '#F39C12', 'Medium': '#3498DB', 'Low': '#27AE60'}
bar_colors = [color_map_risk[r] for r in df_sorted['Risk_Level']]
bars = ax.barh(range(len(df_sorted)), df_sorted['Risk_Score'], color=bar_colors,
               edgecolor='white', linewidth=0.5, height=0.7, alpha=0.9)
ax.set_yticks(range(len(df_sorted)))
ax.set_yticklabels([f"{row['ID']}: {row['Threat_Category']}" for _, row in df_sorted.iterrows()], fontsize=10)
for i, (_, row) in enumerate(df_sorted.iterrows()):
    ax.text(row['Risk_Score'] + 0.1, i, f"{row['Risk_Score']:.2f}", va='center', fontsize=10, fontweight='bold')
ax.set_xlabel('Risk Score (Severity × Likelihood / 10)', fontsize=12, fontweight='bold')
ax.set_title('OWASP ASI Top 10: Risk Score Ranking', fontsize=14, fontweight='bold', pad=15)
ax.set_xlim(0, 10)
ax.axvline(x=8.0, color='red', linestyle='--', alpha=0.5, label='Critical threshold')
ax.axvline(x=7.0, color='orange', linestyle='--', alpha=0.5, label='High threshold')
ax.legend(loc='lower right', fontsize=9)
ax.spines['top'].set_visible(False); ax.spines['right'].set_visible(False)
ax.grid(axis='x', alpha=0.2)
plt.tight_layout()
plt.savefig('chart_risk_ranking.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
print('✅ Risk ranking chart saved')

# %% [markdown]
# ---
# ## 12. 📊 Year-wise Research Distribution

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# (a) Studies by year
year_counts = df_studies['Year'].value_counts().sort_index()
colors_year = ['#3498DB', '#2ECC71', '#E74C3C', '#F39C12']
axes[0].bar(year_counts.index.astype(str), year_counts.values, color=colors_year[:len(year_counts)],
            edgecolor='white', linewidth=1, width=0.6)
for i, (yr, cnt) in enumerate(year_counts.items()):
    axes[0].text(i, cnt + 0.5, str(cnt), ha='center', fontweight='bold', fontsize=12)
axes[0].set_title('(a) Studies by Year', fontsize=13, fontweight='bold')
axes[0].set_ylabel('Number of Studies', fontsize=11)
axes[0].set_ylim(0, max(year_counts) + 5)
axes[0].spines['top'].set_visible(False); axes[0].spines['right'].set_visible(False)

# (b) Studies by category — explicit order to match colors
cat_order = ['ATK','SUR','DEF','THR','FRM']
cat_labels = {'ATK':'Attack Research','SUR':'Survey/Review','DEF':'Defensive AI',
              'THR':'Threat Analysis','FRM':'Framework'}
cat_colors = {'ATK':'#E74C3C','SUR':'#3498DB','DEF':'#2ECC71','THR':'#F39C12','FRM':'#9B59B6'}
cat_counts_ordered = df_studies['Category'].value_counts().reindex(cat_order)

wedges, texts, autotexts = axes[1].pie(
    cat_counts_ordered.values,
    labels=[f"{cat_labels[c]}\n({v})" for c, v in cat_counts_ordered.items()],
    colors=[cat_colors[c] for c in cat_order],
    autopct='%1.1f%%', startangle=90, pctdistance=0.75,
    wedgeprops=dict(edgecolor='white', linewidth=2))
for t in autotexts:
    t.set_fontsize(9); t.set_fontweight('bold')
axes[1].set_title('(b) Studies by Research Theme', fontsize=13, fontweight='bold')

plt.suptitle('Distribution of 75 Included Studies', fontsize=15, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('chart_study_distribution.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
print('✅ Distribution chart saved')

# %% [markdown]
# ---
# ## 13. 📊 Severity-Likelihood Gap Analysis

# %%
fig, ax = plt.subplots(figsize=(12, 6))
df_gap = df_owasp.sort_values('Severity_Likelihood_Gap', ascending=False)
gap_colors = ['#E74C3C' if g > 1.0 else '#F39C12' if g > 0.5 else '#3498DB'
              for g in df_gap['Severity_Likelihood_Gap']]
bars = ax.bar(range(len(df_gap)), df_gap['Severity_Likelihood_Gap'],
              color=gap_colors, edgecolor='white', linewidth=0.5, width=0.6)
ax.set_xticks(range(len(df_gap)))
ax.set_xticklabels([f"{row['ID']}\n{row['Short_Name']}" for _, row in df_gap.iterrows()], fontsize=9, ha='center')
for i, (_, row) in enumerate(df_gap.iterrows()):
    ax.text(i, row['Severity_Likelihood_Gap'] + 0.05, f"{row['Severity_Likelihood_Gap']:.1f}",
            ha='center', fontweight='bold', fontsize=10)
ax.set_ylabel('Gap (Severity − Likelihood)', fontsize=12, fontweight='bold')
ax.set_title('Severity–Likelihood Gap Analysis\n(Higher gap = severe but less likely; priority for proactive defense)',
             fontsize=13, fontweight='bold', pad=15)
ax.axhline(y=0, color='black', linewidth=0.5)
ax.spines['top'].set_visible(False); ax.spines['right'].set_visible(False)
ax.grid(axis='y', alpha=0.2)
plt.tight_layout()
plt.savefig('chart_gap_analysis.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
print('✅ Gap analysis chart saved')

# %% [markdown]
# ---
# ## 14. 📊 Exploitability vs. Impact Quadrant

# %%
fig, ax = plt.subplots(figsize=(12, 9))
ax.axhline(y=8.25, color='gray', linestyle='--', alpha=0.4)
ax.axvline(x=5.5, color='gray', linestyle='--', alpha=0.4)
ax.text(8.0, 9.8, 'HIGH IMPACT\nHARD TO EXPLOIT\n(Monitor)', ha='center',
        fontsize=10, color='gray', alpha=0.6, style='italic')
ax.text(3.0, 9.8, 'HIGH IMPACT\nEASY TO EXPLOIT\n(Critical Priority)', ha='center',
        fontsize=10, color='red', alpha=0.6, style='italic', fontweight='bold')
ax.text(3.0, 6.5, 'LOW IMPACT\nEASY TO EXPLOIT\n(Quick Fixes)', ha='center',
        fontsize=10, color='orange', alpha=0.6, style='italic')
ax.text(8.0, 6.5, 'LOW IMPACT\nHARD TO EXPLOIT\n(Low Priority)', ha='center',
        fontsize=10, color='green', alpha=0.6, style='italic')
color_map_risk = {'Critical': '#E74C3C', 'High': '#F39C12', 'Medium': '#3498DB', 'Low': '#27AE60'}
colors = [color_map_risk[r] for r in df_owasp['Risk_Level']]
sizes = [n * 60 for n in df_owasp['Num_Studies']]
ax.scatter(df_owasp['Exploitability'], df_owasp['Potential_Impact'],
           s=sizes, c=colors, alpha=0.75, edgecolors='white', linewidth=2, zorder=5)
for i, row in df_owasp.iterrows():
    ax.annotate(f"{row['ID']}", (row['Exploitability'], row['Potential_Impact']),
                textcoords='offset points', xytext=(12, 5), fontsize=10, fontweight='bold',
                bbox=dict(boxstyle='round,pad=0.2', facecolor='white', alpha=0.8))
ax.set_xlabel('Exploitability (10 − Attack Complexity)', fontsize=12, fontweight='bold')
ax.set_ylabel('Potential Impact', fontsize=12, fontweight='bold')
ax.set_title('Exploitability vs. Impact Prioritization Quadrant', fontsize=14, fontweight='bold', pad=15)
ax.set_xlim(1, 9); ax.set_ylim(6, 10.2)
ax.spines['top'].set_visible(False); ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig('chart_exploitability_quadrant.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
print('✅ Exploitability quadrant chart saved')

# %% [markdown]
# ---
# ## 15. 📊 Research Category × Threat Stacked Bar

# %%
cross_data = {}
for threat, study_list in study_to_threat.items():
    cat_counts_t = df_studies[df_studies['ID'].isin(study_list)]['Category'].value_counts()
    cross_data[threat] = cat_counts_t
df_cross = pd.DataFrame(cross_data).fillna(0).astype(int)
df_cross = df_cross.reindex(['ATK','SUR','DEF','THR','FRM'])
fig, ax = plt.subplots(figsize=(14, 7))
cat_colors_stack = {'ATK':'#E74C3C','SUR':'#3498DB','DEF':'#2ECC71','THR':'#F39C12','FRM':'#9B59B6'}
bottom = np.zeros(len(threat_ids))
for cat in ['ATK','SUR','DEF','THR','FRM']:
    if cat in df_cross.index:
        vals = df_cross.loc[cat].values
        ax.bar(range(len(threat_ids)), vals, bottom=bottom,
               label=f"{cat} ({cat_labels.get(cat, cat)})",
               color=cat_colors_stack[cat], edgecolor='white', linewidth=0.5, width=0.7)
        bottom += vals
ax.set_xticks(range(len(threat_ids)))
ax.set_xticklabels([f"{tid}\n{sn}" for tid, sn in zip(df_owasp['ID'], df_owasp['Short_Name'])], fontsize=9)
ax.set_ylabel('Number of Supporting Studies', fontsize=12, fontweight='bold')
ax.set_title('Research Category Composition per OWASP ASI Threat', fontsize=14, fontweight='bold', pad=15)
ax.legend(loc='upper right', fontsize=9, framealpha=0.9)
ax.spines['top'].set_visible(False); ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig('chart_category_composition.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
print('✅ Category composition chart saved')

# %% [markdown]
# ---
# ## 16. 📊 Correlation Matrix

# %%
corr_cols = ['Severity','Likelihood','Attack_Complexity','Potential_Impact',
             'Risk_Score','Num_Studies','Exploitability','Composite_Risk']
corr_matrix = df_owasp[corr_cols].corr()
fig, ax = plt.subplots(figsize=(10, 8))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool), k=1)
sns.heatmap(corr_matrix, mask=mask, annot=True, fmt='.2f', cmap='RdBu_r',
            center=0, vmin=-1, vmax=1, square=True,
            linewidths=1, linecolor='white', ax=ax,
            cbar_kws={'shrink': 0.8, 'label': 'Correlation'})
ax.set_title('Correlation Matrix: OWASP ASI Top 10 Dimensions', fontsize=14, fontweight='bold', pad=15)
plt.tight_layout()
plt.savefig('chart_correlation_matrix.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
print('✅ Correlation matrix saved')

# %% [markdown]
# ---
# ## 17. 📊 Venue Distribution

# %%
def classify_venue(venue):
    v = venue.lower()
    if 'arxiv' in v: return 'arXiv'
    elif 'ieee' in v: return 'IEEE'
    elif 'acm' in v: return 'ACM'
    elif 'usenix' in v: return 'USENIX'
    elif 'ndss' in v: return 'NDSS'
    elif 'neurips' in v or 'icml' in v or 'iclr' in v or 'acl' in v or 'emnlp' in v or 'naacl' in v or 'colm' in v or 'icassp' in v: return 'ML/NLP Conf'
    elif 'springer' in v or 'elsevier' in v: return 'Springer/Elsevier'
    elif 'owasp' in v or 'nist' in v or 'csa' in v or 'anthropic' in v: return 'Industry/Gov'
    else: return 'Other'

df_studies['Venue_Group'] = df_studies['Venue'].apply(classify_venue)
venue_counts = df_studies['Venue_Group'].value_counts()
fig, ax = plt.subplots(figsize=(10, 6))
venue_colors = ['#3498DB','#E74C3C','#2ECC71','#F39C12','#9B59B6','#1ABC9C','#34495E','#E67E22','#95A5A6']
bars = ax.barh(range(len(venue_counts)), venue_counts.values,
               color=venue_colors[:len(venue_counts)], edgecolor='white', height=0.6)
ax.set_yticks(range(len(venue_counts)))
ax.set_yticklabels(venue_counts.index, fontsize=11)
for i, v in enumerate(venue_counts.values):
    ax.text(v + 0.3, i, str(v), va='center', fontweight='bold', fontsize=11)
ax.set_xlabel('Number of Studies', fontsize=12, fontweight='bold')
ax.set_title('Publication Venue Distribution (75 Studies)', fontsize=14, fontweight='bold', pad=15)
ax.spines['top'].set_visible(False); ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig('chart_venue_distribution.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
print('✅ Venue distribution chart saved')

# %% [markdown]
# ---
# ## 18. 📊 Composite Risk Comparison

# %%
fig, ax = plt.subplots(figsize=(14, 6))
x = np.arange(len(df_owasp))
width = 0.25
ax.bar(x - width, df_owasp['Risk_Score'], width, label='Risk Score (S×L/10)',
       color='#E74C3C', alpha=0.85, edgecolor='white')
ax.bar(x, df_owasp['Composite_Risk'], width, label='Composite Risk (weighted)',
       color='#3498DB', alpha=0.85, edgecolor='white')
ax.bar(x + width, df_owasp['Exploitability'], width, label='Exploitability (10-Complexity)',
       color='#2ECC71', alpha=0.85, edgecolor='white')
ax.set_xticks(x)
ax.set_xticklabels([f"{row['ID']}\n{row['Short_Name']}" for _, row in df_owasp.iterrows()], fontsize=9)
ax.set_ylabel('Score', fontsize=12, fontweight='bold')
ax.set_title('Multi-Metric Risk Comparison\n(Risk Score vs. Composite Risk vs. Exploitability)',
             fontsize=14, fontweight='bold', pad=15)
ax.set_ylim(0, 10)
ax.legend(loc='upper right', fontsize=10)
ax.grid(axis='y', alpha=0.2)
ax.spines['top'].set_visible(False); ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig('chart_composite_risk.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
print('✅ Composite risk chart saved')

# %% [markdown]
# ---
# ## 19. 📊 Year × Category Grouped Bar

# %%
year_cat = pd.crosstab(df_studies['Year'], df_studies['Category'])
year_cat = year_cat.reindex(columns=['ATK','SUR','DEF','THR','FRM'], fill_value=0)
fig, ax = plt.subplots(figsize=(12, 6))
year_cat.plot(kind='bar', ax=ax, color=[cat_colors[c] for c in year_cat.columns],
              edgecolor='white', linewidth=0.5, width=0.75)
ax.set_xlabel('Year', fontsize=12, fontweight='bold')
ax.set_ylabel('Number of Studies', fontsize=12, fontweight='bold')
ax.set_title('Research Category Distribution by Year', fontsize=14, fontweight='bold', pad=15)
ax.legend([cat_labels.get(c, c) for c in year_cat.columns], loc='upper left', fontsize=9)
ax.set_xticklabels(year_cat.index, rotation=0)
ax.spines['top'].set_visible(False); ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.savefig('chart_year_category.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
print('✅ Year × Category chart saved')

# %% [markdown]
# ---
# ## 20. 📊 Qualitative Classification Decision Flowchart

# %%
from matplotlib.patches import FancyBboxPatch

fig, ax = plt.subplots(figsize=(14, 16), dpi=150)
ax.set_xlim(0, 14); ax.set_ylim(0, 16); ax.axis('off')
ax.set_facecolor('#fafafa')

fc = {'start':'#2C3E50','decision':'#F7DC6F','process':'#85C1E9',
      'ATK':'#E74C3C','DEF':'#27AE60','SUR':'#3498DB','THR':'#F39C12','FRM':'#9B59B6'}

def draw_box(ax, x, y, w, h, text, color, shape='rect', fs=9, fc2='black'):
    if shape == 'diamond':
        ax.add_patch(plt.Polygon([(x,y+h/2),(x+w/2,y),(x,y-h/2),(x-w/2,y)],
                     facecolor=color, edgecolor='#333', lw=1.5))
    elif shape == 'oval':
        ax.add_patch(mpatches.Ellipse((x,y), w, h, facecolor=color, edgecolor='white', lw=2))
        fc2 = 'white'
    else:
        ax.add_patch(FancyBboxPatch((x-w/2,y-h/2), w, h,
                     boxstyle='round,pad=0.02,rounding_size=0.2',
                     facecolor=color, edgecolor='#333', lw=1.5))
    ax.text(x, y, text, ha='center', va='center', fontsize=fs, color=fc2,
            weight='normal', multialignment='center')

def darr(ax, s, e, txt='', to=(0,0)):
    ax.annotate('', xy=e, xytext=s, arrowprops=dict(arrowstyle='->', color='#333', lw=1.5))
    if txt:
        mx, my = (s[0]+e[0])/2+to[0], (s[1]+e[1])/2+to[1]
        ax.text(mx, my, txt, fontsize=8, ha='center', va='center', color='#333', weight='bold',
                bbox=dict(boxstyle='round', facecolor='white', alpha=0.8, edgecolor='none'))

draw_box(ax, 7, 15.3, 2.5, 0.6, 'Read Full Paper', fc['start'], 'oval', 10)
draw_box(ax, 7, 14.2, 4, 0.7, 'Step 1: Identify Primary\nResearch Focus', fc['process'], fs=9)
darr(ax, (7,14.95), (7,14.55))

draw_box(ax, 7, 12.8, 3.5, 1.2, 'Is it an industry\nframework, guideline,\nor standard?', fc['decision'], 'diamond', 8)
darr(ax, (7,13.85), (7,13.4))
draw_box(ax, 12, 12.8, 2, 0.8, 'FRM\n(n=9)', fc['FRM'], fs=10, fc2='white')
darr(ax, (8.75,12.8), (11,12.8), 'Yes')

draw_box(ax, 7, 11, 3.5, 1.2, 'Is it primarily a\nsurvey, review, or\nfoundational work?', fc['decision'], 'diamond', 8)
darr(ax, (7,12.2), (7,11.6), 'No')
draw_box(ax, 12, 11, 2, 0.8, 'SUR\n(n=18)', fc['SUR'], fs=10, fc2='white')
darr(ax, (8.75,11), (11,11), 'Yes')

draw_box(ax, 7, 9.2, 3.5, 1.2, 'Does it demonstrate\nor develop new\nattack techniques?', fc['decision'], 'diamond', 8)
darr(ax, (7,10.4), (7,9.8), 'No')
draw_box(ax, 12, 9.2, 2, 0.8, 'ATK\n(n=23)', fc['ATK'], fs=10, fc2='white')
darr(ax, (8.75,9.2), (11,9.2), 'Yes')

draw_box(ax, 7, 7.4, 3.5, 1.2, 'Does it propose\ndefense mechanisms\nor security tools?', fc['decision'], 'diamond', 8)
darr(ax, (7,8.6), (7,8), 'No')
draw_box(ax, 12, 7.4, 2, 0.8, 'DEF\n(n=14)', fc['DEF'], fs=10, fc2='white')
darr(ax, (8.75,7.4), (11,7.4), 'Yes')

draw_box(ax, 7, 5.6, 3.5, 1.2, 'Does it analyze\nthreats, vulnerabilities,\nor risk assessment?', fc['decision'], 'diamond', 8)
darr(ax, (7,6.8), (7,6.2), 'No')
draw_box(ax, 12, 5.6, 2, 0.8, 'THR\n(n=11)', fc['THR'], fs=10, fc2='white')
darr(ax, (8.75,5.6), (11,5.6), 'Yes')

draw_box(ax, 7, 4, 3.5, 0.7, 'Re-evaluate: Check\nsecondary focus', fc['process'], fs=9)
darr(ax, (7,5), (7,4.35), 'No')
ax.annotate('', xy=(5.25,12.8), xytext=(5.25,4),
            arrowprops=dict(arrowstyle='->', color='#7f8c8d', lw=1.5, connectionstyle='angle,angleA=0,angleB=90'))
ax.plot([5.25,5.25], [4,4.35], color='#7f8c8d', lw=1.5)

cx = 2
for y, txt in [(12.8,'• OWASP, NIST, CSA, IEEE standards\n• Industry guidelines\n• Governance documents'),
               (11,'• Literature reviews\n• Agent architectures\n• Tool learning surveys'),
               (9.2,'• Prompt injection attacks\n• Jailbreaking methods\n• Autonomous exploitation'),
               (7.4,'• Detection systems\n• Guardrails & filters\n• Sandboxing & privilege control'),
               (5.6,'• RAG poisoning analysis\n• Worm propagation study\n• Vulnerability & risk assessment')]:
    ax.text(cx, y, txt, fontsize=7, va='center', ha='left', color='#666',
            bbox=dict(boxstyle='round', facecolor='#f8f9fa', edgecolor='#ddd'))

summary = 'CLASSIFICATION SUMMARY (n=75)\n━━━━━━━━━━━━━━━━━━━━━━━━\n'
summary += 'ATK: Attack Research        23 (30.7%)\n'
summary += 'SUR: Surveys & Foundations   18 (24.0%)\n'
summary += 'DEF: Defensive Applications  14 (18.7%)\n'
summary += 'THR: Threat Analysis         11 (14.7%)\n'
summary += 'FRM: Industry Frameworks      9 (12.0%)'
ax.text(7, 2.2, summary, fontsize=9, va='center', ha='center', family='monospace',
        bbox=dict(boxstyle='round', facecolor='#ecf0f1', edgecolor='#bdc3c7', lw=2))

legend_elements = [mpatches.Patch(facecolor=fc[k], label=l) for k, l in
    [('start','Start/End'),('decision','Decision'),('process','Process'),
     ('ATK','ATK: Attack'),('DEF','DEF: Defense'),('SUR','SUR: Survey'),
     ('THR','THR: Threat'),('FRM','FRM: Framework')]]
ax.legend(handles=legend_elements, loc='lower right', fontsize=8, framealpha=0.95, fancybox=True, ncol=2)

ax.text(7, 16.2, 'Fig. X: Qualitative Classification Decision Flowchart',
        ha='center', fontsize=14, weight='bold', color=fc['start'])
ax.text(7, 15.8, 'Decision process for categorizing studies in the systematic literature review',
        ha='center', fontsize=10, style='italic', color='gray')

plt.tight_layout()
plt.savefig('fig_classification_flowchart.png', dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
print('✅ Classification Flowchart saved')

# %% [markdown]
# ---
# ## 21. Summary Statistics

# %%
print('='*60)
print('SUMMARY STATISTICS')
print('='*60)
print(f'\n📚 Total studies: {len(df_studies)}')
print(f'\n📅 Year distribution:')
for yr, cnt in df_studies['Year'].value_counts().sort_index().items():
    print(f'   {yr}: {cnt} studies')
print(f'\n🏷️ Category distribution:')
for cat, cnt in df_studies['Category'].value_counts().items():
    print(f'   {cat} ({cat_labels.get(cat, cat)}): {cnt} ({cnt/len(df_studies)*100:.1f}%)')
print(f'\n🎯 OWASP ASI Top 10 Risk Scores:')
for _, row in df_owasp.sort_values('Risk_Score', ascending=False).iterrows():
    print(f"   {row['ID']} {row['Threat_Category']:35s} Risk: {row['Risk_Score']:.2f}  [{row['Risk_Level']}]")
print(f'\n📊 Score statistics:')
for col in ['Severity','Likelihood','Risk_Score','Attack_Complexity','Potential_Impact']:
    print(f'   {col:20s}: mean={df_owasp[col].mean():.2f}, std={df_owasp[col].std():.2f}, '
          f'range=[{df_owasp[col].min():.1f}, {df_owasp[col].max():.1f}]')
total_mappings = sum(len(v) for v in study_to_threat.values())
print(f'\n🔗 Total study-threat mappings: {total_mappings}')
print(f'   Average mappings per threat: {total_mappings/10:.1f}')
print(f'   Studies mapped to ≥1 threat: {(mapping_matrix["Threats_Covered"]>0).sum()}')
print(f'   Studies mapped to ≥2 threats: {(mapping_matrix["Threats_Covered"]>1).sum()}')
print(f'\n📍 Venue distribution:')
for vg, cnt in df_studies['Venue_Group'].value_counts().items():
    print(f'   {vg}: {cnt} ({cnt/len(df_studies)*100:.1f}%)')

print(f'\n📋 Quality Assessment:')
print(f'   Mean QA score: {qa_df["Total"].mean():.2f} / 5.0')
print(f'   Studies scoring ≥ 4.0: {(qa_df["Total"] >= 4.0).sum()} ({(qa_df["Total"] >= 4.0).sum()/len(qa_df)*100:.1f}%)')

# %% [markdown]
# ---
# ## 22. Download All Files

# %%
import os, zipfile
generated = sorted([f for f in os.listdir('.') if f.endswith(('.png', '.csv'))])
print('📁 Generated files:')
for f in generated:
    print(f'   📄 {f:45s} ({os.path.getsize(f)/1024:.1f} KB)')
with zipfile.ZipFile('owasp_slr_analysis_updated.zip', 'w') as zf:
    for f in generated: zf.write(f)
print(f'\n📦 All files zipped: owasp_slr_analysis_updated.zip')
try:
    from google.colab import files
    files.download('owasp_slr_analysis_updated.zip')
    print('⬇️ Download started!')
except ImportError:
    print('ℹ️ Not running in Colab — files saved to current directory')
